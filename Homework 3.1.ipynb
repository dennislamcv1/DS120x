# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("AirQualityUCI.csv")

# %%
df
# Out:
#                DateTime  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0    3/10/2004 18:00:00     2.6         1360       150      11.9
# 1    3/10/2004 19:00:00     2.0         1292       112       9.4
# 2    3/10/2004 20:00:00     2.2         1402        88       9.0
# 3    3/10/2004 21:00:00     2.2         1376        80       9.2
# 4    3/10/2004 22:00:00     1.6         1272        51       6.5
# ..                  ...     ...          ...       ...       ...
# 822  4/30/2004 20:00:00     4.4         1449       501      19.5
# 823  4/30/2004 21:00:00     3.1         1363       234      15.1
# 824  4/30/2004 22:00:00     3.0         1371       212      14.6
# 825  4/30/2004 23:00:00     3.1         1406       275      13.7
# 826    5/1/2004 0:00:00     3.5         1425       275      15.2
#
#      PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0             1046      166          1056      113          1692         1268
# ...

# %% [markdown]
# What is the average NOx concentration in ppb? Round your answer to the first decimal place.

# %%
np.mean(df['NOx(GT)'])
# Out:
# 143.5018137847642

# %% [markdown]
# What is the standard deviation of Benzene (labeled as C6H6(GT) in the data) concentration in microg./m3? Round your answer to the first decimal place.

# %%
np.std(df['C6H6(GT)'])
# Out:
# 7.4136479342949455

# %% [markdown]
# Which of the following best describes the shape of the histogram of the Non Metanic HydroCarbons (labeled NMHC(GT) in data) in microg./m3?

# %%
df['NMHC(GT)'].plot(kind='hist',bins=10)
plt.show()

# %% [markdown]
# Which of the following best describes the relationship between CO concentration (labeled CO(GT) in the data) and NO2 concentration (labeled NO2(GT))?

# %%
plt.figure(figsize=(5,5))
plt.scatter(x=df['CO(GT)'],y=df['NO2(GT)'])
plt.xlabel('CO concentration')
plt.ylabel('NO2 concentration')
plt.show()

# %% [markdown]
# The coefficient of correlation between NOx concentration (labeled NOX(GT)) and NO2 concentration (labeled NO2(GT)) lies in which range?

# %%
df.corr()
# Out:
#                  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  \
# CO(GT)         1.000000     0.936261  0.887167  0.972660       0.958426
# PT08.S1(CO)    0.936261     1.000000  0.781747  0.931368       0.936346
# NMHC(GT)       0.887167     0.781747  1.000000  0.897928       0.875061
# C6H6(GT)       0.972660     0.931368  0.897928  1.000000       0.984834
# PT08.S2(NMHC)  0.958426     0.936346  0.875061  0.984834       1.000000
# NOx(GT)        0.951342     0.922885  0.811182  0.927304       0.926633
# PT08.S3(NOx)  -0.823728    -0.829577 -0.774237 -0.848850      -0.910651
# NO2(GT)        0.861432     0.866579  0.728052  0.846743       0.885023
# PT08.S4(NO2)   0.939921     0.945020  0.848489  0.960811       0.957883
# PT08.S5(O3)    0.882943     0.935011  0.761905  0.896978       0.909100
# T              0.318261     0.324815  0.366976  0.418409       0.445615
# RH            -0.105157    -0.039570 -0.160257 -0.178410      -0.193333
# ...

# %% [markdown]
# Which of the following is the most tightly correlated with PT08.S2 sensor response (labeled PT08.S2(NMHC))?

# %%
df2 =  df.corr()

# %%
df2
# Out:
#                  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  \
# CO(GT)         1.000000     0.936261  0.887167  0.972660       0.958426
# PT08.S1(CO)    0.936261     1.000000  0.781747  0.931368       0.936346
# NMHC(GT)       0.887167     0.781747  1.000000  0.897928       0.875061
# C6H6(GT)       0.972660     0.931368  0.897928  1.000000       0.984834
# PT08.S2(NMHC)  0.958426     0.936346  0.875061  0.984834       1.000000
# NOx(GT)        0.951342     0.922885  0.811182  0.927304       0.926633
# PT08.S3(NOx)  -0.823728    -0.829577 -0.774237 -0.848850      -0.910651
# NO2(GT)        0.861432     0.866579  0.728052  0.846743       0.885023
# PT08.S4(NO2)   0.939921     0.945020  0.848489  0.960811       0.957883
# PT08.S5(O3)    0.882943     0.935011  0.761905  0.896978       0.909100
# T              0.318261     0.324815  0.366976  0.418409       0.445615
# RH            -0.105157    -0.039570 -0.160257 -0.178410      -0.193333
# ...

# %%
df2['PT08.S2(NMHC)']
# Out:
# CO(GT)           0.958426
# PT08.S1(CO)      0.936346
# NMHC(GT)         0.875061
# C6H6(GT)         0.984834
# PT08.S2(NMHC)    1.000000
# NOx(GT)          0.926633
# PT08.S3(NOx)    -0.910651
# NO2(GT)          0.885023
# PT08.S4(NO2)     0.957883
# PT08.S5(O3)      0.909100
# T                0.445615
# RH              -0.193333
# AH               0.325333
# Name: PT08.S2(NMHC), dtype: float64

# %% [markdown]
# Suppose that the sensor that detect the Benzene concentration (6-th column with header ‘‘C6H6(GT)’’) breaks down while other parts work fine. To predict the Benzene concentration, the value of which of the following options is the most useful?

# %%
df2['C6H6(GT)']
# Out:
# CO(GT)           0.972660
# PT08.S1(CO)      0.931368
# NMHC(GT)         0.897928
# C6H6(GT)         1.000000
# PT08.S2(NMHC)    0.984834
# NOx(GT)          0.927304
# PT08.S3(NOx)    -0.848850
# NO2(GT)          0.846743
# PT08.S4(NO2)     0.960811
# PT08.S5(O3)      0.896978
# T                0.418409
# RH              -0.178410
# AH               0.313415
# Name: C6H6(GT), dtype: float64
